# %% [markdown]
# # Cocktail Recommendation

# %% [markdown]
# Goal:
# Create a cocktail recommender
# 1. Scrape reddit for username and cocktails ordered
# 2. Create a recommender using association rules, knn, or some other clustering.
# 3. User interface where you select cocktails you like from a list of cocktails and we spit out recommendation.
#
# 3. Scrape internet for cocktail recipes and make a database of recipes
# 4. Calculate alcohol by volume of cocktails/strength category
#
# 5. Create a more robust recommender that references the recipes as well as association.
#
# 6. User interface saves previous recommendation requests as well as stores information on whether or NOT you liked a cocktail, introducing a new feature of not liking a cocktail.

# %% [markdown]
# ## Step 1: Gathering a list of cocktails
#
# ### Step 1a: Scraping Reddit for cocktails
#
# We will use PRAW, reddit application API, to scrape a couple reddit posts to get a list of cocktails people enjoy ordering. The hard part is sorting people's responses for the key words that I want.

# %%
import praw
import pandas as pd
from praw.models import MoreComments

reddit = praw.Reddit(client_id='ZGRoXTLzJz0hiEW6q6E2Og', client_secret='2f95rsary77FnpfsMKKwmXR-xlRryw', user_agent='scraps')

# first url 
url = "https://www.reddit.com/r/cocktails/comments/178syjl/what_are_your_top_3_favorite_cocktails_and_why/"
submissions = reddit.submission(url=url)
posts = []
for top_level_comment in submissions.comments:
    if isinstance(top_level_comment, MoreComments):
        continue
    posts.append((top_level_comment.author.name, top_level_comment.body))

# second url
url = "https://www.reddit.com/r/cocktails/comments/13ihzpy/rcocktails_top_50/"
submissions = reddit.submission(url=url)
for top_level_comment in submissions.comments:
    if isinstance(top_level_comment, MoreComments):
        continue
    if top_level_comment.author != None:
        posts.append((top_level_comment.author.name, top_level_comment.body))

# convert posts to dataframe with redditor id and text.
posts = pd.DataFrame(posts,columns=["id", "body"])
# remove all deleted posts
indexNames = posts[(posts.body == '[removed]') | (posts.body == '[deleted]')].index
posts.drop(indexNames, inplace=True)
posts
# Out:
#                      id                                               body
# 0           jaykaner411  1. Daiquiri - Especially with good rum (probit...
# 1            dwchambers  This is tough! And I’ve hardly tried a great n...
# 2            MizLucinda  Paper plane - equal parts, all magic. I genera...
# 3               thehza4  1. Sazerac. Just perfection. Love the bourbon ...
# 4    _makebuellerproud_  At the moment? \n\n1.) a well made dirty gin m...
# ..                  ...                                                ...
# 481  aproposofnothing32  Bees Knees\n\nBlack Manhattan\n\nMargarita \n\...
# 482       woelajilliams  Negroni, Mai Tai, Army & Navy, Queen's Park Sw...
# 483           thecal714  Daiquiri\n\nWhiskey Sour\n\nSazerac\n\nPaper J...
# 484          CovfefeFan  Nergroni\nManhattan\nOld Fashioned\nMartini\nL...
# 485             alepoks  Sidecar\n\nMai Tai\n\nBoulevardier\n\nOld fash...
#
# [486 rows x 2 columns]

# %%
# preprocessing the text in each post to help our nlp model detect cocktails more accurately. 
processedText = []
for post in posts['body']:
    # common characters used to end sentences or start a new bullet. We want to remove these so that our model doesn't have to work so hard trying to identify what numbers or special characters are part of the cocktail name or not. Now there's a space between these special characters that might be commonly misinterpreted. 
    to_replace = ['.', '-', '\n', ',', '/']
    for c in to_replace:
        post = post.replace(c, ' . ')
    post = post.lower()
    processedText.append(post)

posts["preprocessed"] = processedText # add the processed strings with stop words removed as a new column in the posts dataframe. 

posts
# Out:
#                      id                                               body  \
# 0           jaykaner411  1. Daiquiri - Especially with good rum (probit...
# 1            dwchambers  This is tough! And I’ve hardly tried a great n...
# 2            MizLucinda  Paper plane - equal parts, all magic. I genera...
# 3               thehza4  1. Sazerac. Just perfection. Love the bourbon ...
# 4    _makebuellerproud_  At the moment? \n\n1.) a well made dirty gin m...
# ..                  ...                                                ...
# 481  aproposofnothing32  Bees Knees\n\nBlack Manhattan\n\nMargarita \n\...
# 482       woelajilliams  Negroni, Mai Tai, Army & Navy, Queen's Park Sw...
# 483           thecal714  Daiquiri\n\nWhiskey Sour\n\nSazerac\n\nPaper J...
# 484          CovfefeFan  Nergroni\nManhattan\nOld Fashioned\nMartini\nL...
# 485             alepoks  Sidecar\n\nMai Tai\n\nBoulevardier\n\nOld fash...
#
#                                           preprocessed
# 0    1 .  daiquiri  .  especially with good rum (pr...
# 1    this is tough! and i’ve hardly tried a great n...
# 2    paper plane  .  equal parts .  all magic .  i ...
# 3    1 .  sazerac .  just perfection .  love the bo...
# 4    at the moment?  .  . 1 . ) a well made dirty g...
# ..                                                 ...
# 481  bees knees .  . black manhattan .  . margarita...
# 482  negroni .  mai tai .  army & navy .  queen's p...
# 483  daiquiri .  . whiskey sour .  . sazerac .  . p...
# 484  nergroni . manhattan . old fashioned . martini...
# 485  sidecar .  . mai tai .  . boulevardier .  . ol...
#
# [486 rows x 3 columns]

# %% [markdown]
# ### Step 1b: Using a spaCy NER model to classify cocktails from a body of text.

# %%
# %pip install spacy
# %python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in /Users/xblee/anaconda3/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (0.3.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (2.4.2)
# Requirement already satisfied: jinja2 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (67.8.0)
# Requirement already satisfied: packaging>=20.0 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from spacy) (1.24.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/xblee/anaconda3/lib/python3.11/site-packages (from jinja2->spacy) (2.1.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# UsageError: Line magic function `%python` not found (But cell magic `%%python` exists, did you mean that instead?).

# %%
import spacy

nlp = spacy.load("model-best")

# Process the text to detect the specific entity words
detected_cocktails = []
for post in posts['preprocessed']:
    list = []
    doc = nlp(post)
    for ent in doc.ents:
        list.append(ent.text)
    detected_cocktails.append(list)

posts['processedNER'] = detected_cocktails
posts
# Out:
#                      id                                               body  \
# 0           jaykaner411  1. Daiquiri - Especially with good rum (probit...
# 1            dwchambers  This is tough! And I’ve hardly tried a great n...
# 2            MizLucinda  Paper plane - equal parts, all magic. I genera...
# 3               thehza4  1. Sazerac. Just perfection. Love the bourbon ...
# 4    _makebuellerproud_  At the moment? \n\n1.) a well made dirty gin m...
# ..                  ...                                                ...
# 481  aproposofnothing32  Bees Knees\n\nBlack Manhattan\n\nMargarita \n\...
# 482       woelajilliams  Negroni, Mai Tai, Army & Navy, Queen's Park Sw...
# 483           thecal714  Daiquiri\n\nWhiskey Sour\n\nSazerac\n\nPaper J...
# 484          CovfefeFan  Nergroni\nManhattan\nOld Fashioned\nMartini\nL...
# 485             alepoks  Sidecar\n\nMai Tai\n\nBoulevardier\n\nOld fash...
#
#                                           preprocessed  \
# 0    1 .  daiquiri  .  especially with good rum (pr...
# 1    this is tough! and i’ve hardly tried a great n...
# 2    paper plane  .  equal parts .  all magic .  i ...
# 3    1 .  sazerac .  just perfection .  love the bo...
# 4    at the moment?  .  . 1 . ) a well made dirty g...
# ..                                                 ...
# 481  bees knees .  . black manhattan .  . margarita...
# 482  negroni .  mai tai .  army & navy .  queen's p...
# 483  daiquiri .  . whiskey sour .  . sazerac .  . p...
# 484  nergroni . manhattan . old fashioned . martini...
# 485  sidecar .  . mai tai .  . boulevardier .  . ol...
#
#                                           processedNER
# 0                      [daiquiri, manhattan, highball]
# 1    [jingle bird, naked and famous, sazerac, la be...
# 2    [paper plane, boulevardier, negroni, margarita...
# 3       [sazerac, grog, paloma, oaxacan old fashioned]
# 4    [dirty gin martini, old fashioned, maple syrup...
# ..                                                 ...
# 481  [bees knees, black manhattan, margarita, new y...
# 482                                 [negroni, mai tai]
# 483  [daiquiri, whiskey sour, sazerac, paper jam, c...
# 484  [nergroni, manhattan, old fashioned, martini, ...
# 485  [sidecar, mai tai, boulevardier, old fashioned...
#
# [486 rows x 4 columns]

# %% [markdown]
# ### Step 1c: Data cleaning our resulting list

# %%
# remove rows where the list is empty
posts = posts[posts["processedNER"].str.len() != 0]

# removing all extraneous characters from cocktail names
import re
import string
from unidecode import unidecode

# defining a function to replace special characters. 
def replace_spec(mystring):
    special_char = string.punctuation
    # add the bullet to the list of special characters(punctuations).
    special_char += '•'

    # unidecode is used to convert all diacritic characters into ascii characters (aka removes accent marks)
    mystring = unidecode(mystring)

    # sometimes, we have a bullet and a space so we remove those first. 
    mystring = mystring.replace('• ', '')
    mystring = mystring.replace('&', 'and')
    mystring = mystring.replace('the ', '')

    for c in special_char:
        mystring = mystring.replace(c, '')
    mystring = " ".join(mystring.split())
    #mystring = mystring.strip()
    return mystring

postprocessed = []
for l in posts['processedNER']:
    temp = []
    for item in l:
        cocktail = replace_spec(item)
        temp.append(cocktail)
    postprocessed.append(temp)

posts['postprocessed'] = postprocessed

#posts

# check the count at which all cocktails appear. We can choose to remove if it appears too few times. 

all_cocktails = []
for list in posts['postprocessed']:
    for item in list:
        all_cocktails.append(item)
# Out:
# /var/folders/bt/vmz2h6t112j7lvw7v2yshbmw0000gn/T/ipykernel_4844/3587980226.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   posts['postprocessed'] = postprocessed

# %%
df = pd.DataFrame(all_cocktails, columns=['name'])
ncocktails = df.groupby('name').value_counts().to_frame().reset_index().rename(columns={0:'count'}).sort_values(by=['count','name'], ascending=[False, True])
ncocktails.reset_index(inplace=True)
ncocktails.drop(labels=['index'],axis=1, inplace=True)

# %%
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

for i in range(0,len(ncocktails)):
    for j in range (i, len(ncocktails)):
        # if the name at i is similar to the name at j, but not the same
        if (0.88 < similar(ncocktails['name'][i], ncocktails['name'][j]) < 1):
            print('dropped: ' + ncocktails['name'][j] + ' ---- count: ' + str(ncocktails['count'][j])) 
            print(' and replaced with ' + ncocktails['name'][i] + ' ---- count: ' + str(ncocktails['count'][i]))
            # we should replace the name of j with i, so we save the name of i. 
            ncocktails.loc[j, 'name'] = ncocktails.loc[i,'name']
            continue
# Out:
# dropped: old fashion ---- count: 3
#  and replaced with old fashioned ---- count: 162
# dropped: old fasioned ---- count: 1
#  and replaced with old fashioned ---- count: 162
# dropped: nergroni ---- count: 1
#  and replaced with negroni ---- count: 158
# dropped: margaritas ---- count: 2
#  and replaced with margarita ---- count: 102
# dropped: margharita ---- count: 1
#  and replaced with margarita ---- count: 102
# dropped: daquiri ---- count: 8
#  and replaced with daiquiri ---- count: 101
# dropped: manhatten ---- count: 1
#  and replaced with manhattan ---- count: 82
# dropped: jingle bird ---- count: 1
#  and replaced with jungle bird ---- count: 68
# dropped: boulvardier ---- count: 5
#  and replaced with boulevardier ---- count: 46
# dropped: boulavardier ---- count: 1
#  and replaced with boulevardier ---- count: 46
# dropped: boulivardier ---- count: 1
#  and replaced with boulevardier ---- count: 46
# dropped: naked a famous ---- count: 1
#  and replaced with naked and famous ---- count: 41
# dropped: naked ans famous ---- count: 1
#  and replaced with naked and famous ---- count: 41
# dropped: penecillin ---- count: 1
#  and replaced with penicillin ---- count: 38
# dropped: black manhattan w ---- count: 1
#  and replaced with black manhattan ---- count: 30
# dropped: black manhatten ---- count: 1
#  and replaced with black manhattan ---- count: 30
# dropped: veiux carre ---- count: 1
#  and replaced with vieux carre ---- count: 30
# dropped: vieux care ---- count: 1
#  and replaced with vieux carre ---- count: 30
# dropped: pain killer ---- count: 2
#  and replaced with painkiller ---- count: 28
# dropped: whiskey sours ---- count: 1
#  and replaced with whiskey sour ---- count: 23
# dropped: corpse reviver no ---- count: 7
#  and replaced with corpse reviver 2 ---- count: 20
# dropped: corpse reviver no 2 ---- count: 1
#  and replaced with corpse reviver 2 ---- count: 20
# dropped: corpse reviver no3 ---- count: 1
#  and replaced with corpse reviver 2 ---- count: 20
# dropped: bees knee ---- count: 2
#  and replaced with bees knees ---- count: 19
# dropped: side car ---- count: 3
#  and replaced with sidecar ---- count: 19
# dropped: hemingway daquiri ---- count: 1
#  and replaced with hemingway daiquiri ---- count: 12
# dropped: golf rush ---- count: 1
#  and replaced with gold rush ---- count: 9
# dropped: oaxacan old fashioned ---- count: 4
#  and replaced with oaxaca old fashioned ---- count: 8
# dropped: mezcal margherita ---- count: 1
#  and replaced with mezcal margarita ---- count: 6
# dropped: dark n stormy ---- count: 3
#  and replaced with dark and stormy ---- count: 5
# dropped: a la louisiane ---- count: 3
#  and replaced with la louisiane ---- count: 4
# dropped: la louisianne ---- count: 2
#  and replaced with la louisiane ---- count: 4
# dropped: de la louisiane ---- count: 1
#  and replaced with la louisiane ---- count: 4
# dropped: earl grey marteani ---- count: 2
#  and replaced with earl gray marteani ---- count: 2
# dropped: ranch waters ---- count: 1
#  and replaced with ranch water ---- count: 1
# dropped: suffering bastards ---- count: 1
#  and replaced with suffering bastard ---- count: 1

# %%
# group a new dataframe by the name and add the counts and reset the index.
cocktail_names = ncocktails.groupby('name').sum('count').sort_values('count', ascending=False)
cocktail_names.reset_index(inplace=True)
cocktail_names
# Out:
#                   name  count
# 0        old fashioned    166
# 1              negroni    159
# 2             daiquiri    109
# 3            margarita    105
# 4            last word    102
# ..                 ...    ...
# 255  midnight marauder      1
# 256     midori slipper      1
# 257        midori sour      1
# 258         milk punch      1
# 259       yellow smash      1
#
# [260 rows x 2 columns]

# %%
# manually sort through each cocktail name to make sure that our cocktail_names dataframe contains the proper format for each cocktail. 
index = 0
for name in cocktail_names['name']:
    print(name + ', ' + str(index))
    index += 1

# remove all cocktails with the name you want it to be by hand. 
cocktail_names.replace('dark and stormy', 'dark n stormy', inplace=True)
cocktail_names.replace('ny sour', 'new york sour', inplace=True)
cocktail_names.replace('old', 'old fashioned', inplace=True)
cocktail_names.replace('ramos', 'ramos gin fizz', inplace=True)
cocktail_names.replace('oaxaca of', 'oaxaca old fashioned', inplace=True)
cocktail_names.replace('sazarac', 'sazerac', inplace=True)
cocktail_names.replace('ramos fizz', 'ramos gin fizz', inplace=True)
cocktail_names.replace('old fasioned', 'old fashioned', inplace=True)
cocktail_names.replace('coffee negroni w', 'coffee negroni', inplace=True)
cocktail_names.replace('a spritz', 'aperol spritz', inplace=True)
cocktail_names.replace('maple syrup old fashioned', 'maple old fashioned', inplace=True)
cocktail_names.replace('maple whiskey sours', 'maple whiskey sour', inplace=True)
cocktail_names.replace('mezcal marg', 'mezcal margarita', inplace=True)
cocktail_names.replace('hemingway daq', 'hemingway daiquiri', inplace=True)
cocktail_names.replace('gin style old fashioned', 'gin old fashioned', inplace=True)
cocktail_names.replace('gin tonic', 'gin and tonic', inplace=True)
cocktail_names.replace('hawaiian', 'blue hawaiian', inplace=True)
cocktail_names.replace('hunter s', 'hunters cocktail', inplace=True)
cocktail_names.replace('maguerita', 'margarita', inplace=True)
cocktail_names.replace('dark maple syrup in', 'toronto', inplace=True)

# group a new dataframe by the name and add the counts and reset the index.
cocktail_names = cocktail_names.groupby('name').sum('count').sort_values('count', ascending=False)
cocktail_names.reset_index(inplace=True)
cocktail_names

# create dictionary of cocktail names.
cocktail_dict = []
for cocktail in cocktail_names['name']:
    cocktail_dict.append(cocktail)
# Out:
# old fashioned, 0
# negroni, 1
# daiquiri, 2
# margarita, 3
# last word, 4
# mai tai, 5
# manhattan, 6
# paper plane, 7
# jungle bird, 8
# boulevardier, 9
# martini, 10
# sazerac, 11
# naked and famous, 12
# penicillin, 13
# black manhattan, 14
# vieux carre, 15
# painkiller, 16
# corpse reviver 2, 17
# paloma, 18
# caipirinha, 19
# whiskey sour, 20
# french 75, 21
# gin and tonic, 22
# sidecar, 23
# mojito, 24
# bees knees, 25
# saturn, 26
# aviation, 27
# amaretto sour, 28
# new york sour, 29
# trinidad sour, 30
# hemingway daiquiri, 31
# oaxaca old fashioned, 32
# pina colada, 33
# espresso martini, 34
# la louisiane, 35
# tom collins, 36
# gold rush, 37
# industry sour, 38
# clover club, 39
# singapore sling, 40
# pisco sour, 41
# bijou, 42
# aperol spritz, 43
# gimlet, 44
# ramos gin fizz, 45
# dark and stormy, 46
# mezcal margarita, 47
# kingston negroni, 48
# gin martini, 49
# toronto, 50
# enzoni, 51
# white russian, 52
# final ward, 53
# cosmopolitan, 54
# ti punch, 55
# pina verde, 56
# moscow mule, 57
# el presidente, 58
# jet pilot, 59
# gin basil smash, 60
# jack rose, 61
# hot toddy, 62
# mezcal negroni, 63
# earl gray marteani, 64
# rob roy, 65
# bourbon renewal, 66
# ny sour, 67
# gin gimlet, 68
# godfather, 69
# el diablo, 70
# boston sour, 71
# division, 72
# mule, 73
# champs, 74
# screwdriver, 75
# white lady, 76
# improved whiskey cocktail, 77
# sunflower, 78
# jagerita, 79
# hurricane, 80
# pimms cup, 81
# port au prince, 82
# smoked old fashioned, 83
# hot buttered, 84
# tommys margarita, 85
# monte carlo, 86
# port of spain, 87
# old cuban, 88
# ranch water, 89
# lemon drop, 90
# self starter, 91
# wisconsin old fashioned, 92
# stinger, 93
# white negroni, 94
# mexican firing squad, 95
# planters punch, 96
# mezcal paper plane, 97
# suffering bastard, 98
# 20th century, 99
# dirty gin martini, 100
# elysees, 101
# caesar, 102
# chestnut cup, 103
# gin mule, 104
# dirty martini, 105
# cobras fang, 106
# gandt, 107
# death in afternoon, 108
# angostura colada, 109
# commodore 64, 110
# bloody caesar, 111
# boothby manhattan, 112
# presidente, 113
# puka punch, 114
# ramos, 115
# ramos fizz, 116
# rumgarita, 117
# royal flush, 118
# bobby burns, 119
# rosita, 120
# rare breed, 121
# precision timepiece, 122
# red hook, 123
# risk pool, 124
# greenpoint, 125
# brass rail, 126
# bourbon collins, 127
# port of call, 128
# bourbon smash, 129
# pop quiz, 130
# rye tai, 131
# caribeno, 132
# champs eleysees, 133
# perfect rob roy, 134
# peach bellini, 135
# coffee negroni w, 136
# paper jam, 137
# colorado bulldog, 138
# omukashi, 139
# old vermont, 140
# cucumber gimlet, 141
# rye godfather, 142
# blackbird, 143
# sapphire martini, 144
# whiskey, 145
# artist special, 146
# army, 147
# unnamed, 148
# via roma, 149
# apple martini, 150
# vieux mot, 151
# ward, 152
# whiskey and soda, 153
# basil gin smash, 154
# whiskey buck, 155
# aperol tonic, 156
# aperol sour, 157
# aperol negroni, 158
# widows kiss, 159
# american trilogy, 160
# yellow cactus flower, 161
# basil gimlet, 162
# tobacco road, 163
# dark daiquiri, 164
# signal fire, 165
# sazarac, 166
# blackberry margarita smash, 167
# blackberry bourbon mule, 168
# black scottish, 169
# side, 170
# black magichttps, 171
# sidewinders fang, 172
# black cat, 173
# batanga, 174
# sloe gin fizz, 175
# benjamin barker daiquiri, 176
# bela lugosi, 177
# beezlebub, 178
# bee sting, 179
# tepache cocktail, 180
# test pilot, 181
# old faisoned, 182
# dark maple syrup in, 183
# old, 184
# a spritz, 185
# garibaldi, 186
# jim meehan, 187
# johnny silverhand, 188
# fuzzy navel, 189
# la belle epoque, 190
# french pearl, 191
# last flight, 192
# french martini, 193
# oaxacanite, 194
# lemon drop martini, 195
# lorikeet, 196
# lucien gaudin, 197
# maguerita, 198
# flash blended w, 199
# malort and cola with citrus, 200
# final, 201
# japanese highball, 202
# jamaican dark roast, 203
# gin daisy, 204
# jaeger bomb, 205
# hawaiian, 206
# gordons breakfast, 207
# hemingway daq, 208
# hemingway special, 209
# high five, 210
# highball, 211
# horses neck, 212
# gin tonic, 213
# hot buttered bourbon, 214
# gin style old fashioned, 215
# hunter s, 216
# gin sour, 217
# improved japanese cocktail, 218
# gin rickey, 219
# gin fizz, 220
# maple old fashioned, 221
# maple syrup old fashioned, 222
# maple whiskey sours, 223
# east side, 224
# earl grey martini, 225
# morgenthaler amaretto sour, 226
# morgenthaler sour, 227
# dorflinger, 228
# mr bali hai, 229
# mr black, 230
# dirty shirley, 231
# neptunes wrath, 232
# new orleans buck, 233
# new orleans fizz, 234
# deshler, 235
# nirvana, 236
# noreaster, 237
# oaxaca of, 238
# grog, 239
# monte, 240
# mint julep, 241
# ferroviario, 242
# mind eraser, 243
# martinez, 244
# expensive gins, 245
# enzoni w, 246
# mezcal, 247
# mezcal last word, 248
# mezcal marg, 249
# el guapo, 250
# mezcal old fashioned, 251
# eeyores requiem, 252
# mezcalita, 253
# michelada, 254
# midnight marauder, 255
# midori slipper, 256
# midori sour, 257
# milk punch, 258
# yellow smash, 259

# %%
# create new dataframe with only id, body, and postprocessed. 
cocktail_recs = posts[['id', 'body', 'postprocessed']]

# rename post processed as recommendations. This will hold our recommendations.
cocktail_recs.rename(columns={'postprocessed':'recommendations'}, inplace=True)
# Out:
# /var/folders/bt/vmz2h6t112j7lvw7v2yshbmw0000gn/T/ipykernel_4844/2281204311.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cocktail_recs.rename(columns={'postprocessed':'recommendations'}, inplace=True)

# %%
# %pip install pyspellchecker
# Out:
# Requirement already satisfied: pyspellchecker in /Users/xblee/anaconda3/lib/python3.11/site-packages (0.7.2)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import json

# spell checker using pyspellchecker

# convert cocktail dict into a series and then convert to a json file .
cocktail_corpus = cocktail_names.set_index('name')['count'].to_json()

# writing to cocktail_corpus.json
with open("cocktail_corpus.json", "w") as outfile:
    outfile.write(cocktail_corpus)

def spellchecker(list):
    from spellchecker import SpellChecker

    spell = SpellChecker(language=None, case_sensitive=False, distance=1)
    spell.word_frequency.load_dictionary('./cocktail_corpus.json')

    new_list = []

    for word in list:
        if spell.correction(word) == None:
            print(word + ' is not in our dictionary!')
            inp = input('Type the word if you want to keep it, or type what you want to replace it with: ')
            if inp in cocktail_dict:
                print('Replaced ' + word + ' with ' + inp + '.')
                new_list.append(inp)
            else: 
                cocktail_dict.append(inp)
                print(inp + ' added.')
            continue
        new_list.append(spell.correction(word))
    
    return(new_list)

# test line of code:
# spellchecker(['daquiri', 'black manhatten', 'hawaiian', 'daiquiri', 'ramos', 'ramos'])

# %%
# spell checker using distances. This one is more efficient. 

# define spell checker that will also allow you to change the name of incorrectly spelled words. 
def spellcheck(mystring):
    if mystring in cocktail_dict:
        return (mystring)
    # if our cocktail is not in the list, then we'll pick the most similar one and replace it. 
    for cocktail in cocktail_dict:
        if (similar(mystring, cocktail) > 0.83):
            print('Replaced ' + mystring + ' with ' + cocktail + '.')
            return (cocktail)
    
    # this list will hold more inaccurate matches that might still be possibilities.
    possibilities = []
    for cocktail in cocktail_dict:
        if (similar(mystring, cocktail) > 0.5):
            possibilities.append(cocktail)
            print(mystring + " corrections: " + cocktail + " ----- score: " + str(similar(mystring, cocktail)))

    if 0 < len(possibilities) < 2:
        print('Replaced ' + mystring + ' with ' + possibilities[0] + '.')
        return (possibilities[0])

    # take an input from the user to correct the spelling of the cocktail or possibly add a new cocktail to the dictionary. 
    print(mystring + ' is not in our dictionary! Here are some possibilities: ' + ", ".join(possibilities))
    inp = input('Type the word if you want to keep it, or type what you want to replace it with: ')
    if inp in cocktail_dict:
        print('Replaced ' + mystring + ' with ' + inp + '.')
        return (inp)
    cocktail_dict.append(inp)
    print(inp + ' added.')

def spellcheck_list(list):
    new_list = []
    for word in list:
        new_list.append(spellcheck(word))
    return new_list

#spellcheck_list(['daquiri', 'black manhatten', 'hawaiian', 'daiquiri', 'ramos', 'ramos'])

# %%
# temporary list to hold the list of recommendations. 
recommendations = []

# go through all the recommendations column lists and perform spell check. 
for l in cocktail_recs['recommendations']:
    recommendations.append(spellcheck_list(l))
cocktail_recs['recommendations'] = recommendations

cocktail_recs
# Out:
# Replaced jingle bird with jungle bird.
# Replaced oaxacan old fashioned with oaxaca old fashioned.
# Replaced maple syrup old fashioned with maple old fashioned.
# Replaced sazarac with sazerac.
# old is not in our dictionary! Here are some possibilities:
# Replaced old with old fashioned.
# Replaced earl grey marteani with earl gray marteani.
# Replaced daquiri with daiquiri.
# Replaced golf rush with gold rush.
# Replaced margaritas with margarita.
# Replaced pain killer with painkiller.
# gin tonic corrections: gin and tonic ----- score: 0.8181818181818182
# gin tonic corrections: gin martini ----- score: 0.7
# gin tonic corrections: enzoni ----- score: 0.5333333333333333
# gin tonic corrections: gin gimlet ----- score: 0.5263157894736842
# gin tonic corrections: dirty gin martini ----- score: 0.5384615384615384
# gin tonic corrections: aperol tonic ----- score: 0.5714285714285714
# gin tonic corrections: gin sour ----- score: 0.5882352941176471
# gin tonic corrections: gin daisy ----- score: 0.5555555555555556
# gin tonic corrections: gin fizz ----- score: 0.5882352941176471
# gin tonic corrections: gin rickey ----- score: 0.631578947368421
# gin tonic is not in our dictionary! Here are some possibilities: gin and tonic, gin martini, enzoni, gin gimlet, dirty gin martini, aperol tonic, gin sour, gin daisy, gin fizz, gin rickey
# Replaced gin tonic with gin and tonic.
# Replaced old fashion with old fashioned.
# Replaced naked a famous with naked and famous.
# Replaced ranch waters with ranch water.
# Replaced ramos fizz with ramos gin fizz.
# Replaced gin style old fashioned with gin old fashioned.
# Replaced whiskey sours with whiskey sour.
# Replaced suffering bastards with suffering bastard.
# Replaced side car with sidecar.
# Replaced boulvardier with boulevardier.
# Replaced daquiri with daiquiri.
# Replaced a la louisiane with la louisiane.
# Replaced boulavardier with boulevardier.
# Replaced dark and stormy with dark n stormy.
# a spritz corrections: aperol spritz ----- score: 0.7619047619047619
# Replaced a spritz with aperol spritz.
# Replaced hemingway daquiri with hemingway daiquiri.
# Replaced maple whiskey sours with maple whiskey sour.
# Replaced boulvardier with boulevardier.
# Replaced oaxacan old fashioned with oaxaca old fashioned.
# Replaced daquiri with daiquiri.
# Replaced la louisianne with la louisiane.
# Replaced side car with sidecar.
# Replaced manhatten with manhattan.
# Replaced margaritas with margarita.
# ny sour corrections: whiskey sour ----- score: 0.631578947368421
# ny sour corrections: new york sour ----- score: 0.7
# ny sour corrections: trinidad sour ----- score: 0.6
# ny sour corrections: industry sour ----- score: 0.7
# ny sour corrections: pisco sour ----- score: 0.5882352941176471
# ny sour corrections: boston sour ----- score: 0.6666666666666666
# ny sour corrections: aperol sour ----- score: 0.5555555555555556
# ny sour corrections: midori sour ----- score: 0.5555555555555556
# ny sour corrections: gin sour ----- score: 0.8
# ny sour is not in our dictionary! Here are some possibilities: whiskey sour, new york sour, trinidad sour, industry sour, pisco sour, boston sour, aperol sour, midori sour, gin sour
# Replaced ny sour with new york sour.
# Replaced boulvardier with boulevardier.
# Replaced corpse reviver no with corpse reviver 2.
# Replaced daquiri with daiquiri.
# Replaced side car with sidecar.
# ny sour corrections: whiskey sour ----- score: 0.631578947368421
# ny sour corrections: new york sour ----- score: 0.7
# ny sour corrections: trinidad sour ----- score: 0.6
# ny sour corrections: industry sour ----- score: 0.7
# ny sour corrections: pisco sour ----- score: 0.5882352941176471
# ny sour corrections: boston sour ----- score: 0.6666666666666666
# ny sour corrections: aperol sour ----- score: 0.5555555555555556
# ny sour corrections: midori sour ----- score: 0.5555555555555556
# ny sour corrections: gin sour ----- score: 0.8
# ny sour is not in our dictionary! Here are some possibilities: whiskey sour, new york sour, trinidad sour, industry sour, pisco sour, boston sour, aperol sour, midori sour, gin sour
# Replaced ny sour with new york sour.
# Replaced old fasioned with old fashioned.
# Replaced dark and stormy with dark n stormy.
# Replaced vieux care with vieux carre.
# Replaced black manhattan w with black manhattan.
# maguerita corrections: margarita ----- score: 0.7777777777777778
# maguerita corrections: mai tai ----- score: 0.625
# maguerita corrections: mezcal margarita ----- score: 0.56
# maguerita corrections: jagerita ----- score: 0.8235294117647058
# maguerita corrections: tommys margarita ----- score: 0.56
# maguerita corrections: rosita ----- score: 0.5333333333333333
# maguerita corrections: rumgarita ----- score: 0.6666666666666666
# maguerita corrections: mezcalita ----- score: 0.5555555555555556
# maguerita is not in our dictionary! Here are some possibilities: margarita, mai tai, mezcal margarita, jagerita, tommys margarita, rosita, rumgarita, mezcalita
# Replaced maguerita with margarita.
# Replaced bees knee with bees knees.
# Replaced dark and stormy with dark n stormy.
# Replaced earl grey marteani with earl gray marteani.
# Replaced bees knee with bees knees.
# ramos corrections: ramos gin fizz ----- score: 0.5263157894736842
# ramos corrections: champs ----- score: 0.5454545454545454
# ramos corrections: rosita ----- score: 0.5454545454545454
# ramos is not in our dictionary! Here are some possibilities: ramos gin fizz, champs, rosita
# Replaced ramos with ramos gin fizz.
# Replaced corpse reviver no 2 with corpse reviver 2.
# Replaced corpse reviver no3 with corpse reviver 2.
# Replaced a la louisiane with la louisiane.
# Replaced corpse reviver no with corpse reviver 2.
# Replaced daquiri with daiquiri.
# Replaced boulivardier with boulevardier.
# Replaced pain killer with painkiller.
# Replaced de la louisiane with la louisiane.
# Replaced penecillin with penicillin.
# Replaced black manhatten with black manhattan.
# Replaced old fashion with old fashioned.
# Replaced oaxacan old fashioned with oaxaca old fashioned.
# Replaced daquiri with daiquiri.
# Replaced oaxacan old fashioned with oaxaca old fashioned.
# Replaced corpse reviver no with corpse reviver 2.
# hunter s corrections: hunters cocktail ----- score: 0.5833333333333334
# Replaced hunter s with hunters cocktail.
# Replaced margharita with margarita.
# Replaced dark and stormy with dark n stormy.
# Replaced corpse reviver no with corpse reviver 2.
# Replaced corpse reviver no with corpse reviver 2.
# Replaced corpse reviver no with corpse reviver 2.
# ny sour corrections: whiskey sour ----- score: 0.631578947368421
# ny sour corrections: new york sour ----- score: 0.7
# ny sour corrections: trinidad sour ----- score: 0.6
# ny sour corrections: industry sour ----- score: 0.7
# ny sour corrections: pisco sour ----- score: 0.5882352941176471
# ny sour corrections: boston sour ----- score: 0.6666666666666666
# ny sour corrections: aperol sour ----- score: 0.5555555555555556
# ny sour corrections: midori sour ----- score: 0.5555555555555556
# ny sour corrections: gin sour ----- score: 0.8
# ny sour is not in our dictionary! Here are some possibilities: whiskey sour, new york sour, trinidad sour, industry sour, pisco sour, boston sour, aperol sour, midori sour, gin sour
# Replaced ny sour with new york sour.
# Replaced veiux carre with vieux carre.
# Replaced boulvardier with boulevardier.
# Replaced naked ans famous with naked and famous.
# Replaced la louisianne with la louisiane.
# dark maple syrup in is not in our dictionary! Here are some possibilities:
# Replaced dark maple syrup in with maple old fashioned.
# Replaced mezcal margherita with mezcal margarita.
# Replaced hemingway daq with hemingway daiquiri.
# oaxaca of corrections: oaxaca old fashioned ----- score: 0.6206896551724138
# oaxaca of corrections: oaxacanite ----- score: 0.631578947368421
# oaxaca of is not in our dictionary! Here are some possibilities: oaxaca old fashioned, oaxacanite
# Replaced oaxaca of with oaxaca old fashioned.
# mezcal marg corrections: mezcal margarita ----- score: 0.8148148148148148
# mezcal marg corrections: mezcal negroni ----- score: 0.64
# mezcal marg corrections: mezcal paper plane ----- score: 0.6206896551724138
# mezcal marg corrections: mezcal ----- score: 0.7058823529411765
# mezcal marg corrections: mezcal last word ----- score: 0.6666666666666666
# mezcal marg corrections: mezcal old fashioned ----- score: 0.5161290322580645
# mezcal marg corrections: mezcalita ----- score: 0.7
# mezcal marg is not in our dictionary! Here are some possibilities: mezcal margarita, mezcal negroni, mezcal paper plane, mezcal, mezcal last word, mezcal old fashioned, mezcalita
# Replaced mezcal marg with mezcal margarita.
# Replaced daquiri with daiquiri.
# Replaced boulvardier with boulevardier.
# Replaced a la louisiane with la louisiane.
# Replaced dark and stormy with dark n stormy.
# Replaced daquiri with daiquiri.
# Replaced coffee negroni w with coffee negroni.
# hawaiian corrections: blue hawaiian ----- score: 0.7619047619047619
# Replaced hawaiian with blue hawaiian.
# Replaced old fashion with old fashioned.
# Replaced corpse reviver no with corpse reviver 2.
# Replaced nergroni with negroni.
# /var/folders/bt/vmz2h6t112j7lvw7v2yshbmw0000gn/T/ipykernel_4844/228587809.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cocktail_recs['recommendations'] = recommendations
#                      id                                               body  \
# 0           jaykaner411  1. Daiquiri - Especially with good rum (probit...
# 1            dwchambers  This is tough! And I’ve hardly tried a great n...
# 2            MizLucinda  Paper plane - equal parts, all magic. I genera...
# 3               thehza4  1. Sazerac. Just perfection. Love the bourbon ...
# 4    _makebuellerproud_  At the moment? \n\n1.) a well made dirty gin m...
# ..                  ...                                                ...
# 481  aproposofnothing32  Bees Knees\n\nBlack Manhattan\n\nMargarita \n\...
# 482       woelajilliams  Negroni, Mai Tai, Army & Navy, Queen's Park Sw...
# 483           thecal714  Daiquiri\n\nWhiskey Sour\n\nSazerac\n\nPaper J...
# 484          CovfefeFan  Nergroni\nManhattan\nOld Fashioned\nMartini\nL...
# 485             alepoks  Sidecar\n\nMai Tai\n\nBoulevardier\n\nOld fash...
#
#                                        recommendations
# 0                      [daiquiri, manhattan, highball]
# 1    [jungle bird, naked and famous, sazerac, la be...
# 2    [paper plane, boulevardier, negroni, margarita...
# 3        [sazerac, grog, paloma, oaxaca old fashioned]
# 4    [dirty gin martini, old fashioned, maple old f...
# ..                                                 ...
# 481  [bees knees, black manhattan, margarita, new y...
# 482                                 [negroni, mai tai]
# 483  [daiquiri, whiskey sour, sazerac, paper jam, c...
# 484  [negroni, manhattan, old fashioned, martini, l...
# 485  [sidecar, mai tai, boulevardier, old fashioned...
#
# [481 rows x 3 columns]

# %%
# removing repeats
no_repeats = []
for l in cocktail_recs['recommendations']:
    temp = []
    for item in l:
        if item in temp:
            continue
        temp.append(item)
    no_repeats.append(temp)

cocktail_recs['recommendations'] = no_repeats

cocktail_recs
# Out:
# /var/folders/bt/vmz2h6t112j7lvw7v2yshbmw0000gn/T/ipykernel_4844/873562433.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cocktail_recs['recommendations'] = no_repeats
#                      id                                               body  \
# 0           jaykaner411  1. Daiquiri - Especially with good rum (probit...
# 1            dwchambers  This is tough! And I’ve hardly tried a great n...
# 2            MizLucinda  Paper plane - equal parts, all magic. I genera...
# 3               thehza4  1. Sazerac. Just perfection. Love the bourbon ...
# 4    _makebuellerproud_  At the moment? \n\n1.) a well made dirty gin m...
# ..                  ...                                                ...
# 481  aproposofnothing32  Bees Knees\n\nBlack Manhattan\n\nMargarita \n\...
# 482       woelajilliams  Negroni, Mai Tai, Army & Navy, Queen's Park Sw...
# 483           thecal714  Daiquiri\n\nWhiskey Sour\n\nSazerac\n\nPaper J...
# 484          CovfefeFan  Nergroni\nManhattan\nOld Fashioned\nMartini\nL...
# 485             alepoks  Sidecar\n\nMai Tai\n\nBoulevardier\n\nOld fash...
#
#                                        recommendations
# 0                      [daiquiri, manhattan, highball]
# 1    [jungle bird, naked and famous, sazerac, la be...
# 2    [paper plane, boulevardier, negroni, margarita...
# 3        [sazerac, grog, paloma, oaxaca old fashioned]
# 4    [dirty gin martini, old fashioned, maple old f...
# ..                                                 ...
# 481  [bees knees, black manhattan, margarita, new y...
# 482                                 [negroni, mai tai]
# 483  [daiquiri, whiskey sour, sazerac, paper jam, c...
# 484  [negroni, manhattan, old fashioned, martini, l...
# 485  [sidecar, mai tai, boulevardier, old fashioned...
#
# [481 rows x 3 columns]

# %% [markdown]
# ## Step 2: Building a Recommender
#
# For the next part of this project, I want to create a recommender. Here are some ideas that I have:
#
# #### Frequent Pattern Growth:
# In order to implement frequent pattern growth, we need to one hot encode our recommendations. Then, we can implement an fp growth algo. The tricky part with this association rules algorithm is that we would only be able to input a single cocktail and then use that to gather a recommendation on what other cocktails to try. I want a more robust recommender that can take multiple cocktails into account. However, for a one to one recommendation, this would be quick and simple to implement, given that the fp growth algorithm is included in the mlxtend package.
#
# #### User to User Recommendation:
# Since we have different lists of users, we can try to create a recommendation algorithm that matches us to other users who have rated the same cocktails and try to predict a rating. A lot of the documentation on this form of algorithm uses a rating system. People would rate different movies they have watched, and we would take our input, compare it to other users who have rated other movies similarly, and use that to predict what other items might be rated highly. However, instead of a rating system for our cocktails, we only have a ranked list of cocktails. We could either create a sparse matrix of binary values and approach the recommendation system that way, or we can decide what rating a first place, second place, third place (and so on) cocktail translates to. Fortunately for us, there are a few people who have documented their process of creating a user to user recommendation system with binary or unary data.
#
# I guess we'll try implementing both and seeing what happens!

# %% [markdown]
# ### 2a: Frequent Pattern Growth

# %%
from mlxtend.frequent_patterns import fpgrowth

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth

# take the recommendations column and store as a pandas series
dataset = cocktail_recs['recommendations'].tolist()

dataset

# transform series of lists into one hot encoded dataframe.
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

# return all items and itemsets with at least 60% support.
results = fpgrowth(df, min_support=0.04, use_colnames=True)

results.sort_values(by='support', ascending=False)
# Out:
#      support                      itemsets
# 11  0.347193               (old fashioned)
# 7   0.328482                     (negroni)
# 0   0.222453                    (daiquiri)
# 8   0.218295                   (margarita)
# 17  0.212058                   (last word)
# 12  0.178794                     (mai tai)
# 1   0.172557                   (manhattan)
# 2   0.160083                 (paper plane)
# 3   0.143451                 (jungle bird)
# 36  0.112266      (negroni, old fashioned)
# 9   0.110187                (boulevardier)
# 4   0.097713                     (sazerac)
# 23  0.093555                     (martini)
# 38  0.089397    (old fashioned, margarita)
# 5   0.089397            (naked and famous)
# 26  0.083160     (daiquiri, old fashioned)
# 6   0.081081                  (penicillin)
# 29  0.068607    (manhattan, old fashioned)
# 21  0.066528             (black manhattan)
# 16  0.066528                 (vieux carre)
# 45  0.066528    (old fashioned, last word)
# 44  0.064449          (negroni, last word)
# 30  0.064449          (negroni, manhattan)
# 37  0.064449          (negroni, margarita)
# 20  0.062370                  (painkiller)
# 13  0.060291            (corpse reviver 2)
# 27  0.056133           (negroni, daiquiri)
# 40  0.054054            (negroni, mai tai)
# 10  0.054054                      (paloma)
# 31  0.054054        (negroni, paper plane)
# 19  0.051975                  (caipirinha)
# 41  0.051975      (mai tai, old fashioned)
# 43  0.049896           (daiquiri, mai tai)
# 24  0.049896                (whiskey sour)
# 33  0.049896      (paper plane, last word)
# 32  0.049896  (paper plane, old fashioned)
# 22  0.049896               (gin and tonic)
# 14  0.047817                   (french 75)
# 35  0.045738      (sazerac, old fashioned)
# 18  0.045738                     (sidecar)
# 39  0.043659         (daiquiri, margarita)
# 25  0.043659                      (mojito)
# 42  0.043659          (mai tai, margarita)
# 15  0.043659                  (bees knees)
# 46  0.043659        (last word, margarita)
# 47  0.043659         (daiquiri, last word)
# 48  0.043659      (old fashioned, martini)
# 34  0.041580        (jungle bird, negroni)
# 28  0.041580         (daiquiri, manhattan)

# %% [markdown]
# What we see from our results from using frequent pattern growth is that cocktails are to varied. Our one hot encoded matrix is so sparse that we can barely see any support between each of our cocktails. What we can glean, however is that certain cocktails are related to other cocktails. If people like one cocktail, it's possible to identify a second cocktail to recommend. For example, the support between an old fashioned and a negroni has a support value of 0.11, which is considerably high compared to other relations. We can say that a person who likes an old fashioned, might like a negroni as well.

# %% [markdown]
# ### 2b: Item-Item Recommendation

# %%
def normalized_one_hot(dataset):
    from mlxtend.preprocessing import TransactionEncoder

    te = TransactionEncoder()
    te_ary = te.fit(dataset).transform(dataset)
    df = pd.DataFrame(te_ary, columns=te.columns_)

    # convert all boolean values into binary.
    df = df.replace({True:1, False:0})

    # calculate the norm of each row vector and normalize each row. 
    norm_by_row = df.sum(axis=1)
    df = df.divide(norm_by_row, axis='index')

    return df


# convert list of lists to similarity matrix
def similarity_matrix(dataset):
    df = normalized_one_hot(dataset)

    # calculate pearson coefficient constant (the same as the cosine similarity function).
    data_matrix = df.corr(method='pearson')

    return (data_matrix)

# takes user input on preferred cocktails and returns a list of preferential cocktails
def input_likes():
    inp = ""
    likes = []

    while (inp != 'done'):
        if (inp != ""):
            print("You like: " + str(likes))
        inp = input("What cocktail do you like? If you are done listing your favorite cocktails, write 'done': ")
        
        inp = inp.lower()

        if (inp == 'done'):
            break
        
        inp = replace_spec(inp)
        inp = spellcheck(inp)

        if (inp not in likes):
            likes.append(inp)

    return likes

# %%
# take the recommendations column and store as a pandas series
dataset = cocktail_recs['recommendations'].tolist()

dataset.append(input_likes())

matrix = similarity_matrix(dataset)

matrix
# nlargest function returns the indices with the highest correlation values to the given index. 
#print (data_matrix.loc['negroni'].nlargest(11))
# Out:
# You like: ['old fashioned']
# Replaced negorni with negroni.
# You like: ['old fashioned', 'negroni']
# You like: ['old fashioned', 'negroni', 'blue hawaiian']
# You like: ['old fashioned', 'negroni', 'blue hawaiian']
# You like: ['old fashioned', 'negroni', 'blue hawaiian', 'mojito']
#                          20th century  amaretto sour  american trilogy  \
# 20th century                 1.000000      -0.011237         -0.002943
# amaretto sour               -0.011237       1.000000         -0.007937
# american trilogy            -0.002943      -0.007937          1.000000
# angostura colada            -0.003952      -0.010658         -0.002792
# aperol negroni              -0.002943      -0.007937         -0.002079
# ...                               ...            ...               ...
# white russian               -0.006491      -0.017505         -0.004585
# widows kiss                 -0.002943      -0.007937         -0.002079
# wisconsin old fashioned     -0.004042      -0.010900         -0.002855
# yellow cactus flower        -0.002943       0.201698         -0.002079
# yellow smash                -0.002943      -0.007937         -0.002079
#
#                          angostura colada  aperol negroni  aperol sour  \
# 20th century                    -0.003952       -0.002943    -0.002943
# amaretto sour                   -0.010658       -0.007937    -0.007937
# american trilogy                -0.002792       -0.002079    -0.002079
# angostura colada                 1.000000       -0.002792    -0.002792
# aperol negroni                  -0.002792        1.000000    -0.002079
# ...                                   ...             ...          ...
# white russian                   -0.006156       -0.004585    -0.004585
# widows kiss                     -0.002792       -0.002079    -0.002079
# wisconsin old fashioned         -0.003834       -0.002855    -0.002855
# yellow cactus flower            -0.002792       -0.002079    -0.002079
# yellow smash                    -0.002792       -0.002079    -0.002079
#
#                          aperol spritz  aperol tonic  apple martini      army  \
# 20th century                 -0.008335     -0.002943      -0.002943 -0.002943
# amaretto sour                 0.098614     -0.007937      -0.007937  0.201698
# american trilogy             -0.005888     -0.002079      -0.002079 -0.002079
# angostura colada             -0.007906     -0.002792      -0.002792 -0.002792
# aperol negroni               -0.005888     -0.002079      -0.002079 -0.002079
# ...                                ...           ...            ...       ...
# white russian                -0.012984     -0.004585      -0.004585 -0.004585
# widows kiss                  -0.005888     -0.002079      -0.002079 -0.002079
# wisconsin old fashioned      -0.008085     -0.002855       0.857210 -0.002855
# yellow cactus flower         -0.005888     -0.002079      -0.002079  1.000000
# yellow smash                 -0.005888     -0.002079      -0.002079 -0.002079
#
#                          ...  whiskey and soda  whiskey buck  whiskey sour  \
# 20th century             ...         -0.002943     -0.002943     -0.014541
# amaretto sour            ...         -0.007937     -0.007937     -0.000617
# american trilogy         ...         -0.002079     -0.002079     -0.010271
# angostura colada         ...         -0.002792     -0.002792     -0.013792
# aperol negroni           ...         -0.002079     -0.002079     -0.010271
# ...                      ...               ...           ...           ...
# white russian            ...         -0.004585     -0.004585     -0.022652
# widows kiss              ...         -0.002079     -0.002079     -0.010271
# wisconsin old fashioned  ...         -0.002855     -0.002855      0.080908
# yellow cactus flower     ...         -0.002079     -0.002079     -0.010271
# yellow smash             ...         -0.002079     -0.002079     -0.010271
#
#                          white lady  white negroni  white russian  \
# 20th century              -0.004947      -0.004167      -0.006491
# amaretto sour             -0.013340       0.137152      -0.017505
# american trilogy          -0.003494      -0.002943      -0.004585
# angostura colada          -0.004692      -0.003952      -0.006156
# aperol negroni            -0.003494      -0.002943      -0.004585
# ...                             ...            ...            ...
# white russian             -0.007706      -0.006491       1.000000
# widows kiss               -0.003494      -0.002943      -0.004585
# wisconsin old fashioned   -0.004798      -0.004042      -0.006296
# yellow cactus flower      -0.003494      -0.002943      -0.004585
# yellow smash              -0.003494      -0.002943      -0.004585
#
#                          widows kiss  wisconsin old fashioned  \
# 20th century               -0.002943                -0.004042
# amaretto sour              -0.007937                -0.010900
# american trilogy           -0.002079                -0.002855
# angostura colada           -0.002792                -0.003834
# aperol negroni             -0.002079                -0.002855
# ...                              ...                      ...
# white russian              -0.004585                -0.006296
# widows kiss                 1.000000                -0.002855
# wisconsin old fashioned    -0.002855                 1.000000
# yellow cactus flower       -0.002079                -0.002855
# yellow smash               -0.002079                -0.002855
#
#                          yellow cactus flower  yellow smash
# 20th century                        -0.002943     -0.002943
# amaretto sour                        0.201698     -0.007937
# american trilogy                    -0.002079     -0.002079
# angostura colada                    -0.002792     -0.002792
# aperol negroni                      -0.002079     -0.002079
# ...                                       ...           ...
# white russian                       -0.004585     -0.004585
# widows kiss                         -0.002079     -0.002079
# wisconsin old fashioned             -0.002855     -0.002855
# yellow cactus flower                 1.000000     -0.002079
# yellow smash                        -0.002079      1.000000
#
# [247 rows x 247 columns]

# %%
# the index of what we received from our input will always be the last. 
dataset[-1]

# initialize normalized one hot encoded dataset:
df = normalized_one_hot(dataset)

# index of latest add to dataset. 
user_index = df.index.tolist()[-1]

# user vector extracted from the dataframe.
user_vector = df.iloc[user_index]

# Calculate the score.
score = matrix.dot(user_vector).div(matrix.sum(axis=1))

# Remove the known likes from the recommendation.
score = score.drop(dataset[-1])

# Print the known likes and the top 5 recommendations.
print ("You like: " + str(dataset[-1]))

print("We recommend: \n" + str(score.nlargest(5)))
# Out:
# You like: ['old fashioned', 'negroni', 'blue hawaiian', 'mojito']
# We recommend:
# penicillin          10.372146
# dark n stormy        0.878432
# whiskey sour         0.484964
# naked and famous     0.443066
# black cat            0.400691
# dtype: float64
